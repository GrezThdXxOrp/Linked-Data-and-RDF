# %% [markdown]
# # Task: Find corresponding data in DBpedia and Wikidata

# %% [markdown]
# ## Overview:
# Find instances in DBpedia and Wikidata equivalent/co-refer to the movies in your RDF data set, this means, find resources that you can link to via the _owl:sameAs_ property
#
#
# ## Task Details
#
# 1. Use the SPARQL Endpoints of DBpedia (https://dbpedia.org/sparql) and Wikidata (https://query.wikidata.org) to get the data
# > __Hint__: Try a few queries in the SPARQL endpoints before incporporating the query in your code
# 2. If using Python, you  can query the SPARQL endpoints with RDFLib or SPARQLWrapper. To find the correct match, you can use the title of the movie, its publication date (or year), and/or the directors' names.
# > __Hint__: Exact matches do not always get the desired results, as labels might be different across Knowledge bases, e.g., “Charles Chaplin” vs. “Charlie Chaplin”
# 3. If a match is found, add the one correct _owl:sameAs_ link to the DBpedia and the one correct link to the Wikidata resource to your dataset from Task 1, e.g.,
# `<https://firstname-lastname.org/resource/the_godfather> owl:sameAs  <http://dbpedia.org/resource/The_Godfather>`
# > __Hint__: Use RDFLib to load the data you have saved in Task 1 and add the links to the corresponding movies
#
# <br>
#
# ## Sumission 2:
#
# Save the new dataset containing _owl:sameAs_ statements in N3 in the output folder with the naming __movies_task_2.n3__.

# %% [markdown]
# <br>
#
# ## Your code

# %%
from rdflib import URIRef, Literal, Graph, Namespace
from rdflib.namespace import FOAF, RDF, RDFS, XSD, DC
import urllib
from datetime import datetime
from SPARQLWrapper import SPARQLWrapper, JSON, N3

# %%
sparql_query = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX dc:  <http://purl.org/dc/elements/1.1/>

    Select distinct ?scientist ?name ?birthdate ?description ?thumbnail WHERE {
        # ?scientist rdf:type dbo:Scientist ;           
            rdfs:label ?name ;
            dbo:birthDate ?birthdate; 
            dct:description ?description .
     FILTER ((lang(?name)="en") && (lang(?description)="en") 
                 && (SUBSTR(STR(?birthdate),6)=SUBSTR(STR(bif:curdate('')),6)) 
                 && (STRLEN(STR(?birthdate))>6)) .
     OPTIONAL {?scientist dbo:thumbnail ?thumbnail }.
    }
"""

# There
sparql_query_db = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>

    Select distinct ?movie ?title ?director ?director_name WHERE {
        # ?movie rdf:type dbo:Film ;
            rdfs:label ?title ;
            dbo:director ?director .
        # ?director foaf:name ?director_name .
    FILTER ((lang(?title) = "en")) .
    }
"""

sparql_query_wd = """
    PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>
    PREFIX dbo: <http://dbpedia.org/ontology/>
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
    
    Select distinct ?movie ?title ?director ?director_name WHERE {
        # ?movie rdf
    }

"""

# %%
sparql = SPARQLWrapper("https://dbpedia.org/sparql")
sparql.setQuery(sparql_query_db)

sparql.setReturnFormat(JSON)
results = sparql.query().convert()

# %%
results['results']['bindings']
# Out:
# [{'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/The_Apartment'},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': 'The Apartment'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Billy_Wilder'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Billy Wilder'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/The_Lost_Weekend_(film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'The Lost Weekend (film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Billy_Wilder'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Billy Wilder'}},
#  {'movie': {'type': 'uri',
#    'value': "http://dbpedia.org/resource/Breakfast_at_Tiffany's_(film)"},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': "Breakfast at Tiffany's (film)"},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Blake_Edwards'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Blake Edwards'}},
#  {'movie': {'type': 'uri',
#    'value': "http://dbpedia.org/resource/Gentleman's_Agreement"},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': "Gentleman's Agreement"},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Elia_Kazan'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Elia Kazan'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/On_the_Waterfront'},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': 'On the Waterfront'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Elia_Kazan'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Elia Kazan'}},
#  {'movie': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Powaqqatsi'},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': 'Powaqqatsi'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Godfrey_Reggio'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Godfrey Reggio'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Léon:_The_Professional'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Léon: The Professional'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Luc_Besson'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': '
}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Mammoth_(2006_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Mammoth (2006 film)'},
#   'director': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Tim_Cox'},
#   'director_name': {'type': 'literal', 'xml:lang': 'en', 'value': 'Tim Cox'}},
#  {'movie': {'type': 'uri',
#    'value': "http://dbpedia.org/resource/Ismael's_Ghosts"},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': "Ismael's Ghosts"},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Arnaud_Desplechin'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Arnaud Desplechin'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Once_Upon_a_Time_(1994_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Once Upon a Time (1994 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Bhandit_Rittakol'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Bhandit Rittakol'}},
#  {'movie': {'type': 'uri',
#    'value': "http://dbpedia.org/resource/L'Argent_(1928_film)"},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': "L'Argent (1928 film)"},
#   'director': {'type': 'uri',
#    'value': "http://dbpedia.org/resource/Marcel_L'Herbier"},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': "Marcel L'Herbier"}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/New_Orleans_(film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'New Orleans (film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Arthur_Lubin'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Arthur Lubin'}},
#  {'movie': {'type': 'uri', 'value': 'http://dbpedia.org/resource/Nuit_1'},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': 'Nuit 1'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Anne_Émond'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Anne Émond'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Jai_(2004_Tamil_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Jai (2004 Tamil film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/S._Narayan'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'S. Narayan'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Lorna_(film)'},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': 'Lorna (film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Russ_Meyer'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Russ Meyer'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Infection_(2004_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Infection (2004 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Masayuki_Ochiai'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Masayuki Ochiai'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Nasty_Boys_(film)'},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': 'Nasty Boys (film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Rick_Rosenthal'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Rick Rosenthal'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Kaleidoscope_(1966_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Kaleidoscope (1966 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Jack_Smight'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Jack Smight'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/No_Way_Back_(1995_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'No Way Back (1995 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Frank_Cappello'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Frank Cappello'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Nikki,_Wild_Dog_of_the_North'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Nikki, Wild Dog of the North'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Jack_Couffer'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Jack Couffer'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Hurricane_Smith_(1952_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Hurricane Smith (1952 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Jerry_Hopper'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Jerry Hopper'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Momentum_(2015_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Momentum (2015 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Stephen_Campanelli'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Stephen Campanelli'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Morning_Sun_(film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Morning Sun (film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Carma_Hinton'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Carma Hinton'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Morning_Sun_(film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Morning Sun (film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Carma_Hinton'},
#   'director_name': {'type': 'literal', 'xml:lang': 'en', 'value': '韩倞'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/My_Best_Friend_(2001_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'My Best Friend (2001 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Lakis_Lazopoulos'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Lakis Lazopoulos'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Malla_(film)'},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': 'Malla (film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/V._Ravichandran'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'V. Ravichandran'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Malla_(film)'},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': 'Malla (film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/V._Ravichandran'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'V Ravichandaran'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Michael_(1996_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Michael (1996 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Nora_Ephron'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Nora Ephron'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Jaime_(1999_film)'},
#   'title': {'type': 'literal', 'xml:lang': 'en', 'value': 'Jaime (1999 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/António-Pedro_Vasconcelos'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'António-Pedro Vasconcelos'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Madame_Bovary_(1947_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Madame Bovary (1947 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Carlos_Schlieper'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Carlos Schlieper'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Momentum_(IMAX_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Momentum (IMAX film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Colin_Low_(filmmaker)'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Colin Low'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Imitation_of_Life_(1934_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Imitation of Life (1934 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/John_M._Stahl'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'John M. Stahl'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Magnificent_Obsession_(1935_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Magnificent Obsession (1935 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/John_M._Stahl'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'John M. Stahl'}},
#  {'movie': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Jinxed_(2013_film)'},
#   'title': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Jinxed (2013 film)'},
#   'director': {'type': 'uri',
#    'value': 'http://dbpedia.org/resource/Stephen_Herek'},
#   'director_name': {'type': 'literal',
#    'xml:lang': 'en',
#    'value': 'Stephen Herek'}},
#  ...]

# %%
for line in results['results']['bindings']:
    if 'Pramathesh Barua' in line['director_name']['value'] :
        print(line['director']['value'])
# Out:
# http://dbpedia.org/resource/Pramathesh_Barua
# http://dbpedia.org/resource/Pramathesh_Barua
# http://dbpedia.org/resource/Pramathesh_Barua
